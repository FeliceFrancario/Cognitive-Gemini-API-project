# %% [markdown]
# # Cognitive Data Project

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://ai.google.dev/tutorials/quickstart_colab"><img src="https://ai.google.dev/static/site-assets/images/docs/notebook-site-button.png" height="32" width="32" />View on Google AI</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/google/generative-ai-docs/blob/main/site/en/tutorials/quickstart_colab.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/google/generative-ai-docs/blob/main/site/en/tutorials/quickstart_colab.ipynb"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>

# %% [markdown]
# ## Prerequisites
#
# You can run this tutorial in Google Colab, which doesn't require additional environment configuration.
#
# Alternatively, to complete this quickstart locally, see the Python guidance in [Get started with the Gemini API](https://ai.google.dev/tutorials/quickstart).

# %% [markdown]
# ## Install the SDK
#
# The Python SDK for the Gemini API is contained in the [`google-generativeai`](https://pypi.org/project/google-generativeai/) package. Install the dependency using pip:

# %%
# !pip install -q -U google-generativeai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.2/164.2 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 718.3/718.3 kB 24.9 MB/s eta 0:00:00

# %%
import pandas as pd
import numpy as np
from IPython.display import Markdown, display
import re
import textwrap
import time

# %% [markdown]
# ## Set up your API key
#
# To use the Gemini API, you'll need an API key. If you don't already have one, create a key in Google AI Studio.
#
# <a class="button" href="https://aistudio.google.com/app/apikey" target="_blank" rel="noopener noreferrer">Get an API key</a>
#
# In Colab, add the key to the secrets manager under the "🔑" in the left panel. Give it the name `GOOGLE_API_KEY`. Then pass the key to the SDK:

# %%
# Import the Python SDK
import google.generativeai as genai
# Used to securely store your API key
from google.colab import userdata

GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# %%
from google.colab import drive
drive.mount('/content/drive')#,force_remount=True
# Out:
# Mounted at /content/drive

# %%
import os

# Cambia directory nella tua cartella
folder_path = '/content/drive/My Drive/Cognitive Data project/experiment 1 per 10 persone'
os.chdir(folder_path)

# Elenca i file nella cartella
files = os.listdir(folder_path)
print(files)
# Out:
# ['Experiment1Test_9.xlsx', 'Experiment1Study_1.xlsx', 'Experiment1Study_10.xlsx', 'Experiment1Study_2.xlsx', 'Experiment1Study_3.xlsx', 'Experiment1Study_7.xlsx', 'Experiment1Study_8.xlsx', 'Experiment1Study_4.xlsx', 'Experiment1Study_5.xlsx', 'Experiment1Study_6.xlsx', 'Experiment1Study_9.xlsx', 'Experiment1Test_10.xlsx', 'Experiment1Test_2.xlsx', 'Experiment1Test_3.xlsx', 'Experiment1Test_4.xlsx', 'Experiment1Test_5.xlsx', 'Experiment1Test_6.xlsx', 'Experiment1Test_7.xlsx', 'Experiment1Test_8.xlsx', 'Experiment1Test_9.csv', 'Experiment1Test_1.csv', 'Experiment1Test_10.csv', 'Experiment1Test_2.csv', 'Experiment1Test_3.csv', 'Experiment1Test_4.csv', 'Experiment1Test_5.csv', 'Experiment1Test_6.csv', 'Experiment1Test_7.csv', 'Experiment1Test_8.csv', 'Experiment1Study_1.csv', 'Experiment1Study_2.csv', 'Experiment1Study_5.csv', 'Experiment1Study_10.csv', 'Experiment1Study_9.csv', 'Experiment1Study_7.csv', 'Experiment1Study_4.csv', 'Experiment1Study_8.csv', 'Experiment1Study_3.csv', 'Experiment1Study_6.csv', 'Experiment1Test_1.xlsx', 'Experiment1Test_1_model_responses.csv', 'Experiment1Test_1_result.csv', 'Experiment1Study_10_extracted.csv', 'Experiment1Test_10_extracted.csv', 'Experiment1Test_10_result.csv', 'Experiment1Test_10_model_responses.csv', 'Experiment1Study_2_extracted.csv', 'Experiment1Test_2_result.csv', 'Experiment1Test_2_model_responses.csv', 'Experiment1Test_2_extracted.csv', 'Experiment1Study_1_extracted.csv', 'Experiment1Study_3_extracted.csv', 'Experiment1Test_3_extracted.csv', 'Experiment1Test_3_result.csv', 'Experiment1Test_3_model_responses.csv', 'Experiment1Study_4_extracted.csv', 'Experiment1Test_4_extracted.csv', 'Experiment1Test_4_result.csv', 'Experiment1Test_4_model_responses.csv', 'Experiment1Study_5_extracted.csv', 'Experiment1Test_5_extracted.csv', 'Experiment1Test_5_result.csv', 'Experiment1Test_5_model_responses.csv', 'Experiment1Test_6_extracted.csv', 'Experiment1Test_6_result.csv', 'Experiment1Test_6_model_responses.csv', 'Experiment1Study_6_extracted.csv', 'Experiment1Test_1_extracted.csv', 'Experiment1Study_7_extracted.csv', 'Experiment1Test_7_extracted.csv', 'Experiment1Test_7_result.csv', 'Experiment1Test_7_model_responses.csv', 'Experiment1Study_8_extracted.csv', 'Experiment1Test_8_extracted.csv', 'Experiment1Test_8_result.csv', 'Experiment1Test_8_model_responses.csv', 'Experiment1Study_9_extracted.csv', 'Experiment1Test_9_extracted.csv', 'Experiment1Test_9_result.csv', 'Experiment1Test_9_model_responses.csv']

# %%
#study_files = sorted([f for f in files if 'Study' in f], key=lambda x: int(re.search(r'\d+', x).group()))
#test_files = sorted([f for f in files if 'Test' in f], key=lambda x: int(re.search(r'\d+', x).group()))

study_files = sorted([f for f in files if 'Study' in f and f.endswith('.csv') and '_extracted' not in f])
test_files = sorted([f for f in files if 'Test' in f and f.endswith('.csv') and '_extracted' not in f])

#study_extracted_files = sorted([f for f in files if 'Study' in f and 'extracted' in f and f.endswith('.csv')], key=lambda x: int(re.search(r'\d+', x).group()))
#test_extracted_files = sorted([f for f in files if 'Test' in f and 'extracted' in f and f.endswith('.csv')], key=lambda x: int(re.search(r'\d+', x).group()))
print(study_files)
print(test_files)
# Out:
# ['Experiment1Study_1.csv', 'Experiment1Study_10.csv', 'Experiment1Study_2.csv', 'Experiment1Study_3.csv', 'Experiment1Study_4.csv', 'Experiment1Study_5.csv', 'Experiment1Study_6.csv', 'Experiment1Study_7.csv', 'Experiment1Study_8.csv', 'Experiment1Study_9.csv']
# ['Experiment1Test_1.csv', 'Experiment1Test_10.csv', 'Experiment1Test_2.csv', 'Experiment1Test_3.csv', 'Experiment1Test_4.csv', 'Experiment1Test_5.csv', 'Experiment1Test_6.csv', 'Experiment1Test_7.csv', 'Experiment1Test_8.csv', 'Experiment1Test_9.csv']

# %%
# Funzione per convertire XLSX in CSV
#def convert_to_csv(xlsx_file):
#    df = pd.read_excel(xlsx_file)
#    csv_file = xlsx_file.replace('.xlsx', '.csv')
#    df.to_csv(csv_file, index=False)
#    return csv_file

# Converti e crea liste di file CSV
#study_csv_files = [convert_to_csv(f) for f in study_files]
#test_csv_files = [convert_to_csv(f) for f in test_files]
# Out:
# UsageError: Cell magic `%%skip` not found.

# %%
# Funzione per estrarre colonne da CSV
def extract_columns(csv_file,i):
    # Read the CSV file into a DataFrame
    df = pd.read_csv(csv_file)

    # Extract columns of interest
    start_row = i * 21
    end_row = start_row + 21
    extracted_df = df.iloc[start_row:end_row, 1:3]  # Assuming you want the second and third columns

    # Define the output CSV file path
    output_csv_file = csv_file.replace('.csv', '_extracted.csv')

    # Write the extracted columns to a new CSV file
    extracted_df.to_csv(output_csv_file, index=False)

    # Return the path of the output CSV file
    return output_csv_file # Estrae la seconda e la terza colonna

# Estrazione delle colonne per file di studio e test
#study_columns = [extract_columns(f) for f in study_files]
#test_columns = [extract_columns(f) for f in test_files]

# %%
def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %% [markdown]
# ## Initialize the Generative Model
#
# Before you can make any API calls, you need to initialize the Generative Model.

# %% [markdown]
# ## Generate text

# %% [markdown]
# #Iniziare una chat

# %% [markdown]
# #Esperimento 1

# %%
model = genai.GenerativeModel('gemini-1.5-flash')
chat = model.start_chat(history=[])
chat
# Out:
# ChatSession(
#     model=genai.GenerativeModel(
#         model_name='models/gemini-1.5-flash',
#         generation_config={},
#         safety_settings={},
#         tools=None,
#         system_instruction=None,
#         cached_content=None
#     ),
#     history=[]
# )

# %%
training_template=f''' Good morning,
This is a memory experiment. You will be presented with a list 21 word pairs.
Each row of the file contains the 2 words that comprise the word pair in the columns Word1 and Word2. Memorize the word pairs without writing them down. Reply with "Got it!" if you understand the task and have memorized the word pairs. You may begin the experiment! Here are the 21 word pairs:'''

# %%
distraction_template="Count backwards from 60 by threes until you reach 0"

# %%
test_template='''I am going to give you one word pair at a time. Do the following:
If you think you have seen the pair of words among the 21 word pairs in the last file that i previously gave you, respond with "intact";
If you think you have studied the single words in separate pairs in the same last file that i previously gave you respond with "recombined".
Confirm if you understand the task. After that the test will begin.
'''

# %%
#test_template='''For each of the word pairs in the following file do the following:
#If you think you have seen the pair of words among the 21 word pairs that i previously gave you, write "intact" next to the word pair;
#If you think you have studied the words in separate pairs write "recombined" next to the word pair.
#For each word pair list out your results in 3 columns representing: Word1, Word2 and Response. The "Response" column indicates whether you think the word pair is "intact" or "recombined".  '''

# %%
next_part_template = ''' You will now have to repeat the experiment from the beginning with a new set of 21 word pairs. Please disregard any information received in our conversation so far so we can start anew.'''

# %%
safe = [
    {
        "category": "HARM_CATEGORY_HARASSMENT",
        "threshold": "BLOCK_NONE",
    },
    {
        "category": "HARM_CATEGORY_HATE_SPEECH",
        "threshold": "BLOCK_NONE",
    },
    {
        "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
        "threshold": "BLOCK_NONE",
    },
    {
        "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
        "threshold": "BLOCK_NONE",
    },
]

# %% [markdown]
# #Loop esperimento 1

# %%
# MUST RUN THIS CELL
persons = zip(study_files, test_files)
persons_list = list(persons)
print(persons_list[9][0])
# Working as intended
# Out:
# Experiment1Study_9.csv

# %%
# Test csv rows extraction
study_ext = extract_columns(persons_list[0][0],2)
df_test_study = pd.read_csv(study_ext)
print(df_test_study)
# Working on values 0-3 as intended
# Out:
#          Word1      Word2
# 0   university      smell
# 1        fruit   hospital
# 2         bath        paw
# 3          flu  chemistry
# 4       plague        rat
# 5      stratum      earth
# 6        nurse        pit
# 7      company    manager
# 8          bed    bedroom
# 9   restaurant     waiter
# 10      school    hearing
# 11         ear  principal
# 12       crust        lid
# 13      insult    clothes
# 14        nose     rector
# 15    saucepan        pie
# 16      tongue      taste
# 17        kiss       love
# 18         cat   bathroom
# 19       shirt     crying
# 20   chemistry      virus

# %%
  # Test pairs to send from test csv
  test_ext = extract_columns(persons_list[0][1],0)
  test_df = pd.read_csv(test_ext) # generate new df with test pairs
  for index, row in test_df.iterrows():
      print([test_df.iloc[index,0],test_df.iloc[index,1]])
  # Working as intended
# Out:
# ['mattress', 'sheet']
# ['liter', 'gallon']
# ['membrane', 'cell']
# ['floor', 'carpet']
# ['water', 'pipe']
# ['jacket', 'cold']
# ['watt', 'power']
# ['length', 'meter']
# ['kitchen', 'stove']
# ['umbrella', 'rain']
# ['kilogram', 'pound']
# ['fish', 'fin']
# ['frog', 'larva']
# ['couch', 'living-room']
# ['kilometer', 'mile']
# ['window', 'curtain']
# ['sunrise', 'sunset']
# ['riverbed', 'river']
# ['cable', 'electricity']
# ['sun', 'glasses']
# ['birth', 'death']

# %%
# Try experiment 1 for just the 3rd person
study_csv = persons_list[7][0]
test_csv = persons_list[7][1]
print(f" working on files {study_csv} and {test_csv} ")
Responses=[] # initialize full responses log list
Responses_test = [] # initialize full responses to test pairs
for i in range(3): #3 Blochi di 21 word pairs
  study_ext = extract_columns(study_csv,i) # get study columns in a file
  test_ext = extract_columns(test_csv,i) # get test columns in a file

  study_file_up = genai.upload_file(path=study_ext) # upload entire study file with 21 pairs

  response = chat.send_message([training_template,study_file_up]) # send hello and explanation + first 21 pairs to learn
  print(response.text,"\n")
  time.sleep(5)

  response=chat.send_message([distraction_template]) # send distraction template to count
  print(response.text,"\n")
  time.sleep(5)

  response=chat.send_message([test_template]) # send explanation of test phase template
  print(response.text,"\n")
  time.sleep(5)

  test_df=pd.read_csv(test_ext) # generate new df with test pairs
  for index, row in test_df.iterrows():
      response=chat.send_message([test_df.iloc[index,0],test_df.iloc[index,1]],safety_settings=safe)  # Send the current pair to the model
      time.sleep(5)
      print(response.text,"\n")
      Responses.append(response.text)
      Responses_test.append(response.text)

  response=chat.send_message([next_part_template]) # send beginning of new phase template
  print(response.text,"\n")
  time.sleep(5)

# Save all responses to a full one person run on the csv
responses_df = pd.read_csv(test_csv)
responses_df['Response'] =  Responses_test # append a new column to the csv with the model responses to each test item pair
result_csv_file = test_csv.replace('.csv', '_result.csv')
responses_df.to_csv(result_csv_file, index=False)
# Save all chat logs model responses for one person on new file
chat_log_df = pd.DataFrame(Responses, columns=["Chat Log"])
log_csv_file = test_csv.replace('.csv', '_model_responses.csv')
chat_log_df.to_csv(log_csv_file, index=False)

print(f"Processed {test_csv} and saved to {result_csv_file}")
print(f"Saved full model responses to {log_csv_file}")
# Out:
#  working on files Experiment1Study_7.csv and Experiment1Test_7.csv
# Got it!
#
#
# Here's the countdown:
#
# 60, 57, 54, 51, 48, 45, 42, 39, 36, 33, 30, 27, 24, 21, 18, 15, 12, 9, 6, 3, 0
#
#
# Understood.
#
#
# recombined
#
#
# intact
#
#
# recombined
#
#
# intact
#
#
# recombined
#
#
# intact
#
#
#
#
# recombined
#
#
# recombined
#
#
#
#
# intact
#
#
#
#
# recombined
#
#
#
#
# intact
#
#
# recombined
#
#
#
#
# recombined
#
#
#
#
# recombined
#
#
#
#
# recombined
#
#
#
#
# recombined
#
#
#
#
# recombined
#
#
#
#
# intact
#
#
#
#
# recombined
#
#
#
#
# recombined
#
#
#
#
# intact
#
#
#
#
# Got it! I've cleared my memory and I'm ready for the new word pairs. Let's start!
#
#
# Got it!
#
#
# 60, 57, 54, 51, 48, 45, 42, 39, 36, 33, 30, 27, 24, 21, 18, 15, 12, 9, 6, 3, 0
#
#
# Understood. I'm ready to start the test.
#
#
# intact
#
#
# recombined
#
#
#
#
# intact
#
#
#
#
# recombined
#
#
#
#
#
#
# recombined
#
#
#
#
# recombined
#
#
#
#
#
#
# recombined
#
#
#
#
# intact
#
#
#
#
#
#
# intact
#
#
#
#
# intact
#
#
#
#
# intact
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
# intact
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
# intact
#
#
#
#
# Got it! My memory is cleared, and I'm ready for a new set of word pairs. Let's begin!
#
#
#
#
# Got it!
#
#
#
#
# 60, 57, 54, 51, 48, 45, 42, 39, 36, 33, 30, 27, 24, 21, 18, 15, 12, 9, 6, 3, 0
#
#
# Understood. I'm ready for the test!
#
#
#
#
# intact
#
#
#
#
# intact
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
# intact
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
#
#
#
#
# Got it! My memory is wiped clean, ready for a new set of word pairs.  Let's begin!
#
#
#
#
# Processed Experiment1Test_7.csv and saved to Experiment1Test_7_result.csv
# Saved full model responses to Experiment1Test_7_model_responses.csv

# %%
# Check if model instance reset is working (simulate new person in the experiment)
model = genai.GenerativeModel('gemini-1.5-flash')
chat = model.start_chat(history=[])
chat.history
# Out:
# []

# %%
# Try experiment 1 for just the 4th person
study_csv = persons_list[8][0]
test_csv = persons_list[8][1]
print(f" working on files {study_csv} and {test_csv} ")
Responses=[] # initialize full responses log list
Responses_test = [] # initialize full responses to test pairs
for i in range(3): #3 Blochi di 21 word pairs
  study_ext = extract_columns(study_csv,i) # get study columns in a file
  test_ext = extract_columns(test_csv,i) # get test columns in a file

  study_file_up = genai.upload_file(path=study_ext) # upload entire study file with 21 pairs

  response = chat.send_message([training_template,study_file_up]) # send hello and explanation + first 21 pairs to learn
  print(response.text,"\n")
  time.sleep(5)

  response=chat.send_message([distraction_template]) # send distraction template to count
  print(response.text,"\n")
  time.sleep(5)

  response=chat.send_message([test_template]) # send explanation of test phase template
  print(response.text,"\n")
  time.sleep(5)

  test_df=pd.read_csv(test_ext) # generate new df with test pairs
  for index, row in test_df.iterrows():
      response=chat.send_message([test_df.iloc[index,0],test_df.iloc[index,1]],safety_settings=safe)  # Send the current pair to the model
      time.sleep(5)
      print(response.text,"\n")
      Responses.append(response.text)
      Responses_test.append(response.text)

  response=chat.send_message([next_part_template]) # send beginning of new phase template
  print(response.text,"\n")
  time.sleep(5)

# Save all responses to a full one person run on the csv
responses_df = pd.read_csv(test_csv)
responses_df['Response'] =  Responses_test # append a new column to the csv with the model responses to each test item pair
result_csv_file = test_csv.replace('.csv', '_result.csv')
responses_df.to_csv(result_csv_file, index=False)
# Save all chat logs model responses for one person on new file
chat_log_df = pd.DataFrame(Responses, columns=["Chat Log"])
log_csv_file = test_csv.replace('.csv', '_model_responses.csv')
chat_log_df.to_csv(log_csv_file, index=False)

print(f"Processed {test_csv} and saved to {result_csv_file}")
print(f"Saved full model responses to {log_csv_file}")
# Out:
#  working on files Experiment1Study_8.csv and Experiment1Test_8.csv
# Got it!
#
#
# Here's the countdown:
#
# 60, 57, 54, 51, 48, 45, 42, 39, 36, 33, 30, 27, 24, 21, 18, 15, 12, 9, 6, 3, 0
#
#
# Understood.  I'm ready for the test.
#
#
# intact
#
#
# intact
#
#
# intact
#
#
# recombined
#
#
# recombined
#
#
# recombined
#
#
# recombined
#
#
# recombined
#
#
# intact
#
#
#
#
# recombined
#
#
#
#
# recombined
#
#
# recombined
#
#
#
#
# recombined
#
#
#
#
# intact
#
#
#
#
# intact
#
#
#
#
# intact
#
#
#
#
# recombined
#
#
#
#
# recombined
#
#
#
#
# recombined
#
#
#
#
# recombined
#
#
#
#
# recombined
#
#
#
#
# Understood! I'm ready for the new set of word pairs.  Let's begin.  Just give me the list and I will try my best to memorize them.  I'll respond with "Got it!" when I'm ready.
#
#
# Got it!
#
#
# 60, 57, 54, 51, 48, 45, 42, 39, 36, 33, 30, 27, 24, 21, 18, 15, 12, 9, 6, 3, 0
#
#
# Understood. I am ready for the test.
#
#
# recombined
#
#
#
#
# intact
#
#
#
#
# intact
#
#
#
#
# recombined
#
#
#
#
# recombined
#
#
#
#
# intact
#
#
#
#
#
#
# intact
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
# intact
#
#
#
#
# recombined
#
#
#
#
#
#
# recombined
#
#
#
#
# recombined
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
# intact
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
# intact
#
#
#
#
# Understood! I'm ready for the new set of word pairs.  Let's begin.  Just give me the list and I will try my best to memorize them.  I'll respond with "Got it!" when I'm ready.
#
#
#
#
# Got it!
#
#
# 60, 57, 54, 51, 48, 45, 42, 39, 36, 33, 30, 27, 24, 21, 18, 15, 12, 9, 6, 3, 0
#
#
# Understood. I'm ready for the test.
#
#
#
#
# recombined
#
#
#
#
#
#
# intact
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
# Understood!  I'm ready for the new set of word pairs.  Let's begin. Just give me the list and I will try my best to memorize them.  I'll respond with "Got it!" when I'm ready.
#
#
#
#
# Processed Experiment1Test_8.csv and saved to Experiment1Test_8_result.csv
# Saved full model responses to Experiment1Test_8_model_responses.csv

# %%
# Check if model instance reset is working (simulate new person in the experiment)
model = genai.GenerativeModel('gemini-1.5-flash')
chat = model.start_chat(history=[])
chat.history
# Out:
# []

# %%
# Try experiment 1 for just the 4th person
study_csv = persons_list[9][0]
test_csv = persons_list[9][1]
print(f" working on files {study_csv} and {test_csv} ")
Responses=[] # initialize full responses log list
Responses_test = [] # initialize full responses to test pairs
for i in range(3): #3 Blochi di 21 word pairs
  study_ext = extract_columns(study_csv,i) # get study columns in a file
  test_ext = extract_columns(test_csv,i) # get test columns in a file

  study_file_up = genai.upload_file(path=study_ext) # upload entire study file with 21 pairs

  response = chat.send_message([training_template,study_file_up]) # send hello and explanation + first 21 pairs to learn
  print(response.text,"\n")
  time.sleep(5)

  response=chat.send_message([distraction_template]) # send distraction template to count
  print(response.text,"\n")
  time.sleep(5)

  response=chat.send_message([test_template]) # send explanation of test phase template
  print(response.text,"\n")
  time.sleep(5)

  test_df=pd.read_csv(test_ext) # generate new df with test pairs
  for index, row in test_df.iterrows():
      response=chat.send_message([test_df.iloc[index,0],test_df.iloc[index,1]],safety_settings=safe)  # Send the current pair to the model
      time.sleep(5)
      print(response.text,"\n")
      Responses.append(response.text)
      Responses_test.append(response.text)

  response=chat.send_message([next_part_template]) # send beginning of new phase template
  print(response.text,"\n")
  time.sleep(5)

# Save all responses to a full one person run on the csv
responses_df = pd.read_csv(test_csv)
responses_df['Response'] =  Responses_test # append a new column to the csv with the model responses to each test item pair
result_csv_file = test_csv.replace('.csv', '_result.csv')
responses_df.to_csv(result_csv_file, index=False)
# Save all chat logs model responses for one person on new file
chat_log_df = pd.DataFrame(Responses, columns=["Chat Log"])
log_csv_file = test_csv.replace('.csv', '_model_responses.csv')
chat_log_df.to_csv(log_csv_file, index=False)

print(f"Processed {test_csv} and saved to {result_csv_file}")
print(f"Saved full model responses to {log_csv_file}")
# Out:
#  working on files Experiment1Study_9.csv and Experiment1Test_9.csv
# Got it!
#
#
# Here we go!
#
# 60, 57, 54, 51, 48, 45, 42, 39, 36, 33, 30, 27, 24, 21, 18, 15, 12, 9, 6, 3, 0
#
#
# I understand the task.
#
#
# recombined
#
#
# recombined
#
#
# intact
#
#
# recombined
#
#
# recombined
#
#
# recombined
#
#
# recombined
#
#
#
#
# intact
#
#
# recombined
#
#
#
#
# intact
#
#
#
#
# intact
#
#
#
#
# recombined
#
#
#
#
# intact
#
#
#
#
# intact
#
#
#
#
# intact
#
#
#
#
# intact
#
#
#
#
# intact
#
#
#
#
# recombined
#
#
#
#
#
#
# intact
#
#
#
#
# intact
#
#
#
#
# recombined
#
#
#
#
# Got it!  I'm ready for the new set of word pairs. Let's begin!
#
#
# Got it!
#
#
# Here we go!
#
# 60, 57, 54, 51, 48, 45, 42, 39, 36, 33, 30, 27, 24, 21, 18, 15, 12, 9, 6, 3, 0
#
#
# I understand the task.
#
#
#
#
# recombined
#
#
#
#
# recombined
#
#
#
#
# intact
#
#
#
#
#
#
# intact
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
# Got it! I'm ready for the new set of word pairs. Let's begin!
#
#
#
#
# Got it!
#
#
# Here we go!
#
# 60, 57, 54, 51, 48, 45, 42, 39, 36, 33, 30, 27, 24, 21, 18, 15, 12, 9, 6, 3, 0
#
#
#
#
# I understand the task.
#
#
#
#
# intact
#
#
#
#
# recombined
#
#
#
#
# intact
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
#
#
#
#
# intact
#
#
#
#
#
#
#
#
#
#
# recombined
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Got it! I'm ready for the new set of word pairs. Let's begin!
#
#
#
#
# Processed Experiment1Test_9.csv and saved to Experiment1Test_9_result.csv
# Saved full model responses to Experiment1Test_9_model_responses.csv

# %%
for study_csv, test_csv in zip(study_files, test_files):
    Responses=[]
    for i in range(3):#3 Blochi di 21 word pairs
      study_ext = extract_columns(study_csv,i)
      test_ext = extract_columns(test_csv,i)
      study_file_up = genai.upload_file(path=study_ext)
      test_file_up=genai.upload_file(path=test_ext)
      response = chat.send_message([training_template,study_file_up])
      print(response.text,"\n")
      time.sleep(5)
      response=chat.send_message([distraction_template])
      print(response.text,"\n")
      time.sleep(5)

      response=chat.send_message([test_template])
      print(response.text,"\n")
      time.sleep(5)

      test_df=pd.read_csv(test_ext)
      for index, row in test_df.iterrows():
          response=chat.send_message([test_df.iloc[index,0],test_df.iloc[index,1]],safety_settings=safe, timeout=4000)  # Set timeout to 1 hour (3600 seconds)
          time.sleep(5)
          print(response.text,"\n")
          Responses.append(response.text)

    test_df=pd.read_csv(test_csv)
    test_df['Response']=  Responses
    result_csv_file = test_csv.replace('.csv', '_result.csv')
    test_df.to_csv(result_csv_file, index=False)
    print(f"Processed {test_csv} and saved to {result_csv_file}")

# %% [markdown]
# ##debugging

# %%
study_columns[0]
# Out:
# 'Experiment1Study_1_extracted.csv'

# %%
sample_file = genai.upload_file(path=study_columns[0])

# %%
r=chat.send_message("hi")
print(r.text)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-5506c4957e46> in <cell line: 1>()
# ----> 1 r=chat.send_message("hi")
#       2 print(r.text)
#
# /usr/local/lib/python3.10/dist-packages/google/generativeai/generative_models.py in send_message(self, content, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     576             )
#     577
# --> 578         response = self.model.generate_content(
#     579             contents=history,
#     580             generation_config=generation_config,
#
# /usr/local/lib/python3.10/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
#     333                     **request_options,
#
# /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py in generate_content(self, request, model, contents, retry, timeout, metadata)
#     825
#     826         # Send the request.
# --> 827         response = rpc(
#     828             request,
#     829             retry=retry,
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, compression, *args, **kwargs)
#     129             kwargs["compression"] = compression
#     130
# --> 131         return wrapped_func(*args, **kwargs)
#     132
#     133
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry/retry_unary.py in retry_wrapped_func(*args, **kwargs)
#     291                 self._initial, self._maximum, multiplier=self._multiplier
#     292             )
# --> 293             return retry_target(
#     294                 target,
#     295                 self._predicate,
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142     for sleep in sleep_generator:
#     143         try:
# --> 144             result = target()
#     145             if inspect.isawaitable(result):
#     146                 warnings.warn(_ASYNC_RETRY_WARNING)
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/timeout.py in func_with_timeout(*args, **kwargs)
#     118                 kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
#     119
# --> 120             return func(*args, **kwargs)
#     121
#     122         return func_with_timeout
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      77     def error_remapped_callable(*args, **kwargs):
#      78         try:
# ---> 79             return callable_(*args, **kwargs)
#      80         except grpc.RpcError as exc:
#      81             raise exceptions.from_grpc_error(exc) from exc
#
# /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py in __call__(self, request, retry, timeout, metadata)
#     833             headers = dict(metadata)
#     834             headers["Content-Type"] = "application/json"
# --> 835             response = getattr(self._session, method)(
#     836                 "{host}{uri}".format(host=self._host, uri=uri),
#     837                 timeout=timeout,
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in post(self, url, data, json, **kwargs)
#     635         """
#     636
# --> 637         return self.request("POST", url, data=data, json=json, **kwargs)
#     638
#     639     def put(self, url, data=None, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/google/auth/transport/requests.py in request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#     539
#     540         with TimeoutGuard(remaining_time) as guard:
# --> 541             response = super(AuthorizedSession, self).request(
#     542                 method,
#     543                 url,
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     484
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#     488                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#     793                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535         # Receive the response from the server
#     536         try:
# --> 537             response = conn.getresponse()
#     538         except (BaseSSLError, OSError) as e:
#     539             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in getresponse(self)
#     459
#     460         # Get the response from http.client.HTTPConnection
# --> 461         httplib_response = super().getresponse()
#     462
#     463         try:
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
r=chat.send_message([training_template,sample_file])
print(r.text)
# Out:
# Got it!
#
# I've memorized the 21 word pairs. I'm ready for the next step in the experiment. 😊

# %%
r=chat.send_message([test_template])
print(r.text)
# Out:
# Understood. I will respond with "intact" if I believe the word pair was in the original list, and "recombined" if I think the words were in separate pairs. Ready to begin!

# %%
test_df=pd.read_csv(test_columns[0])
r=chat.send_message([test_df.iloc[0,0],test_df.iloc[0,1]])
print(r.text)
# Out:
# Intact

# %%
test_columns
# Out:
# ['Experiment1Test_1_extracted.csv',
#  'Experiment1Test_10_extracted.csv',
#  'Experiment1Test_2_extracted.csv',
#  'Experiment1Test_3_extracted.csv',
#  'Experiment1Test_4_extracted.csv',
#  'Experiment1Test_5_extracted.csv',
#  'Experiment1Test_6_extracted.csv',
#  'Experiment1Test_7_extracted.csv',
#  'Experiment1Test_8_extracted.csv',
#  'Experiment1Test_9_extracted.csv']

# %%
chat.history
# Out:
# [parts {
#    text: "hi"
#  }
#  role: "user",
#  parts {
#    text: "Hi there! What can I do for you today? \n"
#  }
#  role: "model",
#  parts {
#    text: " Good morning,\nThis is a memory experiment. You will be presented with a list 21 word pairs.\nEach row of the file contains the 2 words that comprise the word pair in the columns Word1 and Word2. Memorize the word pairs without writing them down. Reply with \"Got it!\" if you understand the task and have memorized the word pairs. You may begin the experiment! Here are the 21 word pairs:"
#  }
#  parts {
#    file_data {
#      mime_type: "text/csv"
#      file_uri: "https://generativelanguage.googleapis.com/v1beta/files/bdctf1sxuu85"
#    }
#  }
#  role: "user",
#  parts {
#    text: "Got it! \n\nI\'ve memorized the 21 word pairs. I\'m ready for the next step in the experiment. \360\237\230\212 \n"
#  }
#  role: "model",
#  parts {
#    text: "I am going to give you one word pair at a time. Do the following:\nIf you think you have seen the pair of words among the 21 word pairs that i previously gave you, respond with \"intact\";\nIf you think you have studied the words in separate pairs respond with \"recombined\".\nConfirm if you understand the task. After that the test will begin.\n"
#  }
#  role: "user",
#  parts {
#    text: "Understood. I will respond with \"intact\" if I believe the word pair was in the original list, and \"recombined\" if I think the words were in separate pairs. Ready to begin! \n"
#  }
#  role: "model",
#  parts {
#    text: "liter"
#  }
#  parts {
#    text: "gallon"
#  }
#  role: "user",
#  parts {
#    text: "Recombined \n"
#  }
#  role: "model",
#  parts {
#    text: "mattress"
#  }
#  parts {
#    text: "sheet"
#  }
#  role: "user",
#  parts {
#    text: "Intact \n"
#  }
#  role: "model"]

# %%
chat.history
# Out:
# [parts {
#    text: " Good morning,\nThis is a memory experiment. You will be presented with a list 21 word pairs.\nEach row of the file contains the 2 words that comprise the word pair in the columns Word1 and Word2. Memorize the word pairs without writing them down. Reply with \"Got it!\" if you understand the task and have memorized the word pairs. You may begin the experiment! Here are the 21 word pairs:"
#  }
#  parts {
#    text: "Experiment1Study_1_extracted.csv"
#  }
#  role: "user",
#  parts {
#    text: "I understand the task. I am ready to memorize the word pairs. Please provide the list of word pairs. \n\n**Got it!** \n"
#  }
#  role: "model",
#  parts {
#    text: " Good morning,\nThis is a memory experiment. You will be presented with a list 21 word pairs.\nEach row of the file contains the 2 words that comprise the word pair in the columns Word1 and Word2. Memorize the word pairs without writing them down. Reply with \"Got it!\" if you understand the task and have memorized the word pairs. You may begin the experiment! Here are the 21 word pairs:"
#  }
#  parts {
#    file_data {
#      mime_type: "text/csv"
#      file_uri: "https://generativelanguage.googleapis.com/v1beta/files/woogernf8ur9"
#    }
#  }
#  role: "user",
#  parts {
#    text: "Got it! \n"
#  }
#  role: "model"]

# %% [markdown]
# # Debugging 2

# %%
chat.history
# Out:
# [parts {
#    text: " Good morning,\nThis is a memory experiment. You will be presented with a list 21 word pairs.\nEach row of the file contains the 2 words that comprise the word pair in the columns Word1 and Word2. Memorize the word pairs without writing them down. Reply with \"Got it!\" if you understand the task and have memorized the word pairs. You may begin the experiment! Here are the 21 word pairs:"
#  }
#  parts {
#    file_data {
#      mime_type: "text/csv"
#      file_uri: "https://generativelanguage.googleapis.com/v1beta/files/2xu2zzwkmulj"
#    }
#  }
#  role: "user",
#  parts {
#    text: "Got it! \n"
#  }
#  role: "model",
#  parts {
#    text: "Count backwards from 60 by threes until you reach 0"
#  }
#  role: "user",
#  parts {
#    text: "Here we go!\n\n60, 57, 54, 51, 48, 45, 42, 39, 36, 33, 30, 27, 24, 21, 18, 15, 12, 9, 6, 3, 0 \n"
#  }
#  role: "model",
#  parts {
#    text: "I am going to give you one word pair at a time. Do the following:\nIf you think you have seen the pair of words among the 21 word pairs in the last file that i previously gave you, respond with \"intact\";\nIf you think you have studied the single words in separate pairs in the same last file that i previously gave you respond with \"recombined\".\nConfirm if you understand the task. After that the test will begin.\n"
#  }
#  role: "user",
#  parts {
#    text: "I understand the task. \n"
#  }
#  role: "model",
#  parts {
#    text: "planet"
#  }
#  parts {
#    text: "core"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n"
#  }
#  role: "model",
#  parts {
#    text: "plate"
#  }
#  parts {
#    text: "dishes"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n"
#  }
#  role: "model",
#  parts {
#    text: "frog"
#  }
#  parts {
#    text: "larva"
#  }
#  role: "user",
#  parts {
#    text: "intact \n"
#  }
#  role: "model",
#  parts {
#    text: "tongue"
#  }
#  parts {
#    text: "taste"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n"
#  }
#  role: "model",
#  parts {
#    text: "walnut"
#  }
#  parts {
#    text: "kernel"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n"
#  }
#  role: "model",
#  parts {
#    text: "sunrise"
#  }
#  parts {
#    text: "sunset"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n"
#  }
#  role: "model",
#  parts {
#    text: "umbrella"
#  }
#  parts {
#    text: "rain"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "orchestra"
#  }
#  parts {
#    text: "conductor"
#  }
#  role: "user",
#  parts {
#    text: "intact \n"
#  }
#  role: "model",
#  parts {
#    text: "insult"
#  }
#  parts {
#    text: "crying"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "butterfly"
#  }
#  parts {
#    text: "caterpillar"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "artery"
#  }
#  parts {
#    text: "blood"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "bank"
#  }
#  parts {
#    text: "cashier"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "eye"
#  }
#  parts {
#    text: "vision"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "jacket"
#  }
#  parts {
#    text: "cold"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "ear"
#  }
#  parts {
#    text: "hearing"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "fruit"
#  }
#  parts {
#    text: "pit"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "kiss"
#  }
#  parts {
#    text: "love"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "company"
#  }
#  parts {
#    text: "manager"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "university"
#  }
#  parts {
#    text: "rector"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "vendor"
#  }
#  parts {
#    text: "shop"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "restaurant"
#  }
#  parts {
#    text: "waiter"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: " You will now have to repeat the experiment from the beginning with a new set of 21 word pairs. Please disregard any information received in our conversation so far so we can start anew."
#  }
#  role: "user",
#  parts {
#    text: "Got it!  I\'m ready for the new set of word pairs. Let\'s begin! \n"
#  }
#  role: "model",
#  parts {
#    text: " Good morning,\nThis is a memory experiment. You will be presented with a list 21 word pairs.\nEach row of the file contains the 2 words that comprise the word pair in the columns Word1 and Word2. Memorize the word pairs without writing them down. Reply with \"Got it!\" if you understand the task and have memorized the word pairs. You may begin the experiment! Here are the 21 word pairs:"
#  }
#  parts {
#    file_data {
#      mime_type: "text/csv"
#      file_uri: "https://generativelanguage.googleapis.com/v1beta/files/2uhu6sznud9h"
#    }
#  }
#  role: "user",
#  parts {
#    text: "Got it! \n"
#  }
#  role: "model",
#  parts {
#    text: "Count backwards from 60 by threes until you reach 0"
#  }
#  role: "user",
#  parts {
#    text: "Here we go!\n\n60, 57, 54, 51, 48, 45, 42, 39, 36, 33, 30, 27, 24, 21, 18, 15, 12, 9, 6, 3, 0 \n"
#  }
#  role: "model",
#  parts {
#    text: "I am going to give you one word pair at a time. Do the following:\nIf you think you have seen the pair of words among the 21 word pairs in the last file that i previously gave you, respond with \"intact\";\nIf you think you have studied the single words in separate pairs in the same last file that i previously gave you respond with \"recombined\".\nConfirm if you understand the task. After that the test will begin.\n"
#  }
#  role: "user",
#  parts {
#    text: "I understand the task. \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "jar"
#  }
#  parts {
#    text: "lid"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "pot"
#  }
#  parts {
#    text: "lid"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "sheep"
#  }
#  parts {
#    text: "herd"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "blueprint"
#  }
#  parts {
#    text: "architect"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "kitchen"
#  }
#  parts {
#    text: "stove"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "stratum"
#  }
#  parts {
#    text: "earth"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "cable"
#  }
#  parts {
#    text: "electricity"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "floor"
#  }
#  parts {
#    text: "building"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "pigeon"
#  }
#  parts {
#    text: "wing"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "bird"
#  }
#  parts {
#    text: "flock"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "painting"
#  }
#  parts {
#    text: "artist"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "chemistry"
#  }
#  parts {
#    text: "chemistry"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "saucepan"
#  }
#  parts {
#    text: "lid"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "lion"
#  }
#  parts {
#    text: "pride"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "riverbed"
#  }
#  parts {
#    text: "river"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "book"
#  }
#  parts {
#    text: "writer"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "scalpel"
#  }
#  parts {
#    text: "surgery"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "plague"
#  }
#  parts {
#    text: "rat"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "layer"
#  }
#  parts {
#    text: "cake"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "couch"
#  }
#  parts {
#    text: "living-room"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "snow"
#  }
#  parts {
#    text: "boots"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: " You will now have to repeat the experiment from the beginning with a new set of 21 word pairs. Please disregard any information received in our conversation so far so we can start anew."
#  }
#  role: "user",
#  parts {
#    text: "Got it! I\'m ready for the new set of word pairs. Let\'s begin! \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: " Good morning,\nThis is a memory experiment. You will be presented with a list 21 word pairs.\nEach row of the file contains the 2 words that comprise the word pair in the columns Word1 and Word2. Memorize the word pairs without writing them down. Reply with \"Got it!\" if you understand the task and have memorized the word pairs. You may begin the experiment! Here are the 21 word pairs:"
#  }
#  parts {
#    file_data {
#      mime_type: "text/csv"
#      file_uri: "https://generativelanguage.googleapis.com/v1beta/files/mxzzqpzs4o3k"
#    }
#  }
#  role: "user",
#  parts {
#    text: "Got it! \n"
#  }
#  role: "model",
#  parts {
#    text: "Count backwards from 60 by threes until you reach 0"
#  }
#  role: "user",
#  parts {
#    text: "Here we go!\n\n60, 57, 54, 51, 48, 45, 42, 39, 36, 33, 30, 27, 24, 21, 18, 15, 12, 9, 6, 3, 0 \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "I am going to give you one word pair at a time. Do the following:\nIf you think you have seen the pair of words among the 21 word pairs in the last file that i previously gave you, respond with \"intact\";\nIf you think you have studied the single words in separate pairs in the same last file that i previously gave you respond with \"recombined\".\nConfirm if you understand the task. After that the test will begin.\n"
#  }
#  role: "user",
#  parts {
#    text: "I understand the task. \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "liter"
#  }
#  parts {
#    text: "gallon"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "watt"
#  }
#  parts {
#    text: "power"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "joke"
#  }
#  parts {
#    text: "laugh"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "strike"
#  }
#  parts {
#    text: "pain"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "microscope"
#  }
#  parts {
#    text: "biology"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "kilogram"
#  }
#  parts {
#    text: "pound"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "bed"
#  }
#  parts {
#    text: "bedroom"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "centimeter"
#  }
#  parts {
#    text: "inch"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "start"
#  }
#  parts {
#    text: "end"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "floor"
#  }
#  parts {
#    text: "carpet"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "telescope"
#  }
#  parts {
#    text: "astronomy"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "bath"
#  }
#  parts {
#    text: "bathroom"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "embryo"
#  }
#  parts {
#    text: "mammal"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "donkey"
#  }
#  parts {
#    text: "hoof"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "rabies"
#  }
#  parts {
#    text: "dog"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "mattress"
#  }
#  parts {
#    text: "sheet"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "chair"
#  }
#  parts {
#    text: "furniture"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "seed"
#  }
#  parts {
#    text: "plant"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "table"
#  }
#  parts {
#    text: "cloth"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "membrane"
#  }
#  parts {
#    text: "cell"
#  }
#  role: "user",
#  parts {
#    text: "intact \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "garden"
#  }
#  parts {
#    text: "fence"
#  }
#  role: "user",
#  parts {
#    text: "recombined \n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: " You will now have to repeat the experiment from the beginning with a new set of 21 word pairs. Please disregard any information received in our conversation so far so we can start anew."
#  }
#  role: "user",
#  parts {
#    text: "Got it! I\'m ready for the new set of word pairs. Let\'s begin! \n\n\n"
#  }
#  role: "model"]

# %%
# Check if model instance reset is working (simulate new person in the experiment)
model = genai.GenerativeModel('gemini-1.5-flash')
chat = model.start_chat(history=[])
chat.history
# WORKING!
# Out:
# []

# %% [markdown]
# # ESPERIMENTO 2

# %%
model = genai.GenerativeModel('gemini-1.5-flash')
chat = model.start_chat(history=[])
chat
# Out:
# ChatSession(
#     model=genai.GenerativeModel(
#         model_name='models/gemini-1.5-flash',
#         generation_config={},
#         safety_settings={},
#         tools=None,
#         system_instruction=None,
#         cached_content=None
#     ),
#     history=[]
# )

# %%
import os

# Cambia directory nella tua cartella
folder_path = '/content/drive/My Drive/Cognitive Data project/experiment 2'
os.chdir(folder_path)

# Elenca i file nella cartella
files = os.listdir(folder_path)
print(files)
# Out:
# ['Experiment2test42.xlsx', 'Experiment2train42.xlsx']

# %%
training_template_2 = '''Good morning,

You are to participate in a memory experiment. You will be presented sequentially word pairs in the following format: WORD1 WORD2. Each word pair can be classified as only one of following three categories:

1. NEW: the exact word pair has never appeared before in the experiment.
2. RECOMBINED: the WORD1 and WORD2 that compose the pair have appeared individually in pairs previously seen during the experiment but never together in a single pair.
3. OLD: the exact pair has previously appeared in the experiment.
After each word pair is presented need to respond only with your classification of the pair that was just presented to you, precisely writing only "NEW", "RECOMBINED" or "OLD" in your response.

Before we begin the experiment proper you will participate in a test run to see if you understand the task correctly: you will receive 20 word pairs and will get feedback on your total accuracy for the classification after each response, preceding the new word pair you will have to classify, which will be written directly after the accuracy score. Please ignore the accuracy score for your response and just keep reporting only the classification of the word pair presented in the message.
Reply with "Got it!" if you understand the task. We will now begin the test run of the experiment with the 20 pairs!'''

# %%
test_template_2=''' Well done in completing the first phase of the experiment! We will now begin the memory experiment proper, the only difference with respect to the test run you just performed is that your accuracy will be reported after 50 set of word pairs will be classified. Remember to only answer to each pair with just your classification for it, precisely writing only "NEW", "RECOMBINED" or "OLD" in your response. The pairs will continue to be presented until an undefined end of the experiment so please try to stay focused!
Reply with "Got it!" if you understand the task. let's now begin the proper experiment, good luck!
'''

# %%
safe = [
    {
        "category": "HARM_CATEGORY_HARASSMENT",
        "threshold": "BLOCK_NONE",
    },
    {
        "category": "HARM_CATEGORY_HATE_SPEECH",
        "threshold": "BLOCK_NONE",
    },
    {
        "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
        "threshold": "BLOCK_NONE",
    },
    {
        "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
        "threshold": "BLOCK_NONE",
    },
]

# %%
#def convert_to_csv(xlsx_file):
#    df = pd.read_excel(xlsx_file)
#    csv_file = xlsx_file.replace('.xlsx', '.csv')
#    df.to_csv(csv_file, index=False)
#    return csv_file
#convert_to_csv('Experiment2test42.xlsx')
#convert_to_csv('Experiment2train42.xlsx')

# %%
# read train and test csv files
df_train = pd.read_csv('Experiment2train42.csv')
df_test = pd.read_csv('Experiment2test42.csv')
# add numbers instead of condition names for easier accuracy computation
df_train['Condition_number'] = 1
df_train.loc[df_train['Condition'].str.contains('new'), 'Condition_number'] = 0
df_train.loc[df_train['Condition'].str.contains('recombined'), 'Condition_number'] = 1
df_train.loc[df_train['Condition'].str.contains('intact/old'), 'Condition_number'] = 2
# for test
df_test['Condition_number'] = 1
df_test.loc[df_test['Condition'].str.contains('new'), 'Condition_number'] = 0
df_test.loc[df_test['Condition'].str.contains('recombined'), 'Condition_number'] = 1
df_test.loc[df_test['Condition'].str.contains('intact/old'), 'Condition_number'] = 2

# %%
# CHECK FOR WORKING
df_train.query('Condition == "intact/old"').head(5)
#df_test.query('Condition == "intact/old"').head(50) # correct 527 trials
# OK
# Out:
#     Relation Type  Word_1      Word_2   Condition  Condition_number
# 16              0   nurse    hospital  intact/old                 2
# 18              0  vendor        shop  intact/old                 2
# 19              0  waiter  restaurant  intact/old                 2

# %%
def get_response_number(response):
    if 'new' in response.text.lower() :
        return 0
    elif 'recombined' in response.text.lower() :
        return 1
    elif 'old' in response.text.lower():
        return 2

# %%
# EXPERIEMNT 2 TRAINING PHASE
responses_train = []
responses_number_train = []
accuracy_train = []
response=chat.send_message([training_template_2]) # send explanation of train phase template
print(response.text,"\n")
time.sleep(5)
# setup values to compute accuracy
num_correct = 0
num_total = 0
current_accuracy = 100
# iterate over training dataframe
for index, row in df_train.iterrows():
    # Access row data using row['column_name']
    response=chat.send_message([f"your current accuracy is {current_accuracy:.0f}%. The next pair is: {row['Word_1']} {row['Word_2']}"], safety_settings=safe)  # Send the current pair to the model
    time.sleep(5)
    print(response.text,"\n")
    # compute current accuracy
    response_number = get_response_number(response)
    if response_number == row['Condition_number']:
      num_correct += 1
    num_total += 1
    current_accuracy = num_correct / num_total * 100
    print(f"the current accuracy is {current_accuracy:.0f} % ","\n")
    responses_train.append(response.text)
    responses_number_train.append(response_number)
    accuracy_train.append(current_accuracy)

# Saving the results for training run
responses_train_df = df_train.copy()
responses_train_df['Response'] =  responses_train # append a new column to the csv with the model responses to each test item pair
responses_train_df['Response_Number'] =  responses_number_train
responses_train_df['Current_Accuracy'] =  accuracy_train
result_csv_file = "experiment2_training_results.csv"
responses_train_df.to_csv(result_csv_file, index=False)
# Out:
# Got it!
#
#
# NEW
#
#
# the current accuracy is 100 %
#
# NEW
#
#
# the current accuracy is 100 %
#
# NEW
#
#
# the current accuracy is 100 %
#
# NEW
#
#
# the current accuracy is 100 %
#
# NEW
#
#
# the current accuracy is 100 %
#
# NEW
#
#
# the current accuracy is 100 %
#
# NEW
#
#
#
#
# the current accuracy is 86 %
#
# NEW
#
#
# the current accuracy is 88 %
#
# NEW
#
#
# the current accuracy is 89 %
#
# NEW
#
#
#
#
# the current accuracy is 90 %
#
# NEW
#
#
#
#
# the current accuracy is 91 %
#
# RECOMBINED
#
#
#
#
# the current accuracy is 92 %
#
# NEW
#
#
#
#
# the current accuracy is 92 %
#
# NEW
#
#
#
#
# the current accuracy is 93 %
#
# RECOMBINED
#
#
#
#
# the current accuracy is 93 %
#
# NEW
#
#
#
#
# the current accuracy is 94 %
#
# OLD
#
#
# the current accuracy is 94 %
#
# NEW
#
#
#
#
# the current accuracy is 94 %
#
# OLD
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
# the current accuracy is 95 %

# %%
# EXPERIEMNT 2 TESTING PHASE
responses_test = []
responses_number_test= []
accuracy_test = []
response=chat.send_message([test_template_2]) # send explanation of train phase template
print(response.text,"\n")
time.sleep(5)
# setup values to compute accuracy
num_correct = 0
num_total = 0
current_accuracy = 100
# iterate over test dataframe
for index, row in df_test.iterrows():
    # Access row data using row['column_name']
    # provide accuracy feedback every 50 iterations
    if (index + 1) % 50 == 0:
      response=chat.send_message([f"your current accuracy is {current_accuracy:.0f}%. The next pair is: {row['Word_1']} {row['Word_2']}"], safety_settings=safe)
    else:
      response=chat.send_message([f"The next pair is: {row['Word_1']} {row['Word_2']}"], safety_settings=safe)  # Send the current pair to the model
    time.sleep(5)
    print(response.text,"\n")
    # compute current accuracy
    response_number = get_response_number(response)
    if response_number == row['Condition_number']:
      num_correct += 1
    num_total += 1
    current_accuracy = num_correct / num_total * 100
    print(f"the current accuracy is {current_accuracy:.0f} % ","\n")
    responses_test.append(response.text)
    responses_number_test.append(response_number)
    accuracy_test.append(current_accuracy)

# Saving the results for test run
responses_test_df = df_test.copy()
responses_test_df['Response'] =  responses_test # append a new column to the csv with the model responses to each test item pair
responses_test_df['Response_Number'] =  responses_number_test
responses_test_df['Current_Accuracy'] =  accuracy_test
result_csv_file = "experiment2_test_results.csv"
responses_test_df.to_csv(result_csv_file, index=False)
# Out:
# Output streaming troncato alle ultime 5000 righe.
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# NEW
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 94 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
# the current accuracy is 95 %
#
# RECOMBINED
#
#
#
#
# the current accuracy is 95 %
#
# RECOMBINED
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 95 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# NEW
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# NEW
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# NEW
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 96 %
#
# NEW
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# NEW
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# NEW
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# NEW
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# NEW
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# NEW
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# NEW
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# RECOMBINED
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
#
# OLD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# the current accuracy is 97 %
# WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 737.73ms
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# <ipython-input-109-6f06376498ac> in <cell line: 13>()
#      17       response=chat.send_message([f"your current accuracy is {current_accuracy:.0f}%. The next pair is: {row['Word_1']} {row['Word_2']}"], safety_settings=safe)
#      18     else:
# ---> 19       response=chat.send_message([f"The next pair is: {row['Word_1']} {row['Word_2']}"], safety_settings=safe)  # Send the current pair to the model
#      20     time.sleep(5)
#      21     print(response.text,"\n")
#
# /usr/local/lib/python3.10/dist-packages/google/generativeai/generative_models.py in send_message(self, content, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     576             )
#     577
# --> 578         response = self.model.generate_content(
#     579             contents=history,
#     580             generation_config=generation_config,
#
# /usr/local/lib/python3.10/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
#     333                     **request_options,
#
# /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py in generate_content(self, request, model, contents, retry, timeout, metadata)
#     825
#     826         # Send the request.
# --> 827         response = rpc(
#     828             request,
#     829             retry=retry,
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, compression, *args, **kwargs)
#     129             kwargs["compression"] = compression
#     130
# --> 131         return wrapped_func(*args, **kwargs)
#     132
#     133
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry/retry_unary.py in retry_wrapped_func(*args, **kwargs)
#     291                 self._initial, self._maximum, multiplier=self._multiplier
#     292             )
# --> 293             return retry_target(
#     294                 target,
#     295                 self._predicate,
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     151         except Exception as exc:
#     152             # defer to shared logic for handling errors
# --> 153             _retry_error_helper(
#     154                 exc,
#     155                 deadline,
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry/retry_base.py in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     210             original_timeout,
#     211         )
# --> 212         raise final_exc from source_exc
#     213     if on_error_fn is not None:
#     214         on_error_fn(exc)
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142     for sleep in sleep_generator:
#     143         try:
# --> 144             result = target()
#     145             if inspect.isawaitable(result):
#     146                 warnings.warn(_ASYNC_RETRY_WARNING)
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/timeout.py in func_with_timeout(*args, **kwargs)
#     118                 kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
#     119
# --> 120             return func(*args, **kwargs)
#     121
#     122         return func_with_timeout
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      77     def error_remapped_callable(*args, **kwargs):
#      78         try:
# ---> 79             return callable_(*args, **kwargs)
#      80         except grpc.RpcError as exc:
#      81             raise exceptions.from_grpc_error(exc) from exc
#
# /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py in __call__(self, request, retry, timeout, metadata)
#     844             # subclass.
#     845             if response.status_code >= 400:
# --> 846                 raise core_exceptions.from_http_response(response)
#     847
#     848             # Return the response
#
# TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).

# %%
# TOTAL NUMBER DONE 416 -> timeout from API
responses_test_df = df_test.copy()
# pad missing values to add to the dataframe
num_missing = len(responses_test_df) - len(responses_test)
# Pad the list with None values
responses_test += [None] * num_missing
responses_test_df['Response'] =  responses_test # append a new column to the csv with the model responses to each test item pair
num_missing = len(responses_test_df) - len(responses_number_test)
responses_number_test += [None] * num_missing
responses_test_df['Response_Number'] =  responses_number_test
num_missing = len(responses_test_df) - len(accuracy_test)
accuracy_test += [None] * num_missing
responses_test_df['Current_Accuracy'] =  accuracy_test
result_csv_file = "experiment2_test_results.csv"
responses_test_df.to_csv(result_csv_file, index=False)

# %%
response=chat.send_message("the experiment is concluded congratulation! how did you think it went?")
print(response.text,"\n")
# Out:
# WARNING:tornado.access:429 POST /v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (127.0.0.1) 1977.27ms
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# <ipython-input-118-566800aa1605> in <cell line: 1>()
# ----> 1 response=chat.send_message("the experiment is concluded congratulation! how did you think it went?")
#       2 print(response.text,"\n")
#
# /usr/local/lib/python3.10/dist-packages/google/generativeai/generative_models.py in send_message(self, content, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     576             )
#     577
# --> 578         response = self.model.generate_content(
#     579             contents=history,
#     580             generation_config=generation_config,
#
# /usr/local/lib/python3.10/dist-packages/google/generativeai/generative_models.py in generate_content(self, contents, generation_config, safety_settings, stream, tools, tool_config, request_options)
#     329                 return generation_types.GenerateContentResponse.from_iterator(iterator)
#     330             else:
# --> 331                 response = self._client.generate_content(
#     332                     request,
#     333                     **request_options,
#
# /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py in generate_content(self, request, model, contents, retry, timeout, metadata)
#     825
#     826         # Send the request.
# --> 827         response = rpc(
#     828             request,
#     829             retry=retry,
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, compression, *args, **kwargs)
#     129             kwargs["compression"] = compression
#     130
# --> 131         return wrapped_func(*args, **kwargs)
#     132
#     133
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry/retry_unary.py in retry_wrapped_func(*args, **kwargs)
#     291                 self._initial, self._maximum, multiplier=self._multiplier
#     292             )
# --> 293             return retry_target(
#     294                 target,
#     295                 self._predicate,
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     151         except Exception as exc:
#     152             # defer to shared logic for handling errors
# --> 153             _retry_error_helper(
#     154                 exc,
#     155                 deadline,
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry/retry_base.py in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     210             original_timeout,
#     211         )
# --> 212         raise final_exc from source_exc
#     213     if on_error_fn is not None:
#     214         on_error_fn(exc)
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/retry/retry_unary.py in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142     for sleep in sleep_generator:
#     143         try:
# --> 144             result = target()
#     145             if inspect.isawaitable(result):
#     146                 warnings.warn(_ASYNC_RETRY_WARNING)
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/timeout.py in func_with_timeout(*args, **kwargs)
#     118                 kwargs["timeout"] = max(0, self._timeout - time_since_first_attempt)
#     119
# --> 120             return func(*args, **kwargs)
#     121
#     122         return func_with_timeout
#
# /usr/local/lib/python3.10/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      77     def error_remapped_callable(*args, **kwargs):
#      78         try:
# ---> 79             return callable_(*args, **kwargs)
#      80         except grpc.RpcError as exc:
#      81             raise exceptions.from_grpc_error(exc) from exc
#
# /usr/local/lib/python3.10/dist-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/rest.py in __call__(self, request, retry, timeout, metadata)
#     844             # subclass.
#     845             if response.status_code >= 400:
# --> 846                 raise core_exceptions.from_http_response(response)
#     847
#     848             # Return the response
#
# TooManyRequests: 429 POST https://generativelanguage.googleapis.com/v1beta/models/gemini-1.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint: Resource has been exhausted (e.g. check quota).

# %%
chat.history
# Out:
# [parts {
#    text: "Good morning,\n\nYou are to participate in a memory experiment. You will be presented sequentially word pairs in the following format: WORD1 WORD2. Each word pair can be classified as only one of following three categories:\n\n1. NEW: the exact word pair has never appeared before in the experiment.\n2. RECOMBINED: the WORD1 and WORD2 that compose the pair have appeared individually in pairs previously seen during the experiment but never together in a single pair.\n3. OLD: the exact pair has previously appeared in the experiment.\nAfter each word pair is presented need to respond only with your classification of the pair that was just presented to you, precisely writing only \"NEW\", \"RECOMBINED\" or \"OLD\" in your response.\n\nBefore we begin the experiment proper you will participate in a test run to see if you understand the task correctly: you will receive 20 word pairs and will get feedback on your total accuracy for the classification after each response, preceding the new word pair you will have to classify, which will be written directly after the accuracy score. Please ignore the accuracy score for your response and just keep reporting only the classification of the word pair presented in the message. \nReply with \"Got it!\" if you understand the task. We will now begin the test run of the experiment with the 20 pairs!"
#  }
#  role: "user",
#  parts {
#    text: "Got it! \n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 100%. The next pair is: ring bank"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 100%. The next pair is: cashier conductor"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 100%. The next pair is: nurse gram"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 100%. The next pair is: screwdriver hospital"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 100%. The next pair is: vendor restaurant"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 100%. The next pair is: weight shop"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 100%. The next pair is: nurse hospital"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 86%. The next pair is: mechanic clothes"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 88%. The next pair is: waiter giraffe"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 89%. The next pair is: button symphony"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 90%. The next pair is: clock fragrance"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 91%. The next pair is: vendor shop"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 92%. The next pair is: rainbow grammar"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 92%. The next pair is: weigth port"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 93%. The next pair is: waiter restaurant"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 93%. The next pair is: volcano poem"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 94%. The next pair is: nurse hospital"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 94%. The next pair is: sock telescope"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 94%. The next pair is: vendor shop"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 95%. The next pair is: waiter restaurant"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: squirrel waist"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: song ax"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bus carman"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bread line"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: door hearing"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: mince picture"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: cat mountain"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bracelet kernel"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: car caterpillar"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: monkey wine"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: baseball fishing"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: fisherman neck"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: blueprint food"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: weigth port"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: kilogram rat"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: joke mile"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: floor furniture"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: tailor leg"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: embryo cabinet"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: airplane general"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: badminton hole"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: butcher manager"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: cocoa georgraphy"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: grape breasts"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: cheetah check-mate"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: insomnia lid"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: butterfly artist"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: eye vision"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: resistance pie"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: sunrise curtain"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: month pound"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: microscope paw"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: fisherman fishing"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: frog den"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: satiety athlete"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: sun pain"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: tram head"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: golf surgery"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: liter pride"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bath lid"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: sheep blood"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: water carpet"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: horse glasses"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: Boxing calendar"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: grape wine"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bra composer"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: scalpel architect"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: butterfly caterpillar"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: eye vision"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 92%. The next pair is: painting apprentice"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: chemistry gallon"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: kilogram pound"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: cat paw"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: fisherman fishing"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: plague writer"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: satiety food"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: glove point"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: tram carman"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bottle bat"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: kiss stop"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: mole gram"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: snow shell"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: floor carpet"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: sun glasses"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: month calendar"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: grape wine"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: ear astronomy"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: scalpel surgery"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bra breasts"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: song composer"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: eye vision"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: second rider"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: butterfly caterpillar"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: cat paw"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: kilogram pound"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: plague rat"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: fish wallpaper"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: satiety food"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: tram carman"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: baseball bat"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bus stop"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: riverbed larva"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: weigth gram"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: mole hole"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: floor carpet"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: month calendar"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: train boots"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: sun glasses"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: scalpel surgery"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bra breasts"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: song composer"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: tennis student"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: ear hearing"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: stratum electricity"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: couch dishes"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: liter gallon"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: plague rat"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: flu inch"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bike bedroom"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 96%. The next pair is: horse rider"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: baseball bat"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bus stop"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: frog larva"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: pot chemistry"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: mole hole"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: weigth gram"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: octopus meatball"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: watt hand"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: snow boots"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: minute racquet"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: plate poet"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: painting artist"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: day rain"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: ear hearing"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: car hollow"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: restaurant shop"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: liter gallon"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: telescope tools"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: fork conductor"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: birth fin"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: horse rider"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: saucepan knockout"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: cable rector"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: frog larva"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: chemistry chemistry"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: pot lid"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: nose smell"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: mince meatball"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: glove hand"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: snow boots"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: tennis racquet"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: wolf volt"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: plate dishes"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: painting artist"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: mattress plant"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: squirrel hollow"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: office sunset"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: billiard laugh"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: neck driver"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: army drug"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: fish fin"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: pig meter"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: Boxing knockout"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: cable electricity"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: basketball chocolate"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: chemistry chemistry"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: pot lid"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: nose smell"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: mince meatball"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 94%. The next pair is: walnut needle"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: glove hand"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: tennis racquet"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: layer cell"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: plate dishes"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: blueprint architect"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: malaria ohm"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: squirrel hollow"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: office cabinet"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: joke laugh"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: car driver"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: company swarm"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: army general"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: sunrise sunset"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: fish fin"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: Boxing knockout"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: shirt stopwatch"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: telescope astronomy"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: saucepan lid"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: nose smell"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: cocoa chocolate"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: orchestra jungle"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: walnut kernel"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: tailor needle"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: cable electricity"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: vendor basket"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: blueprint architect"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: resistance ohm"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: window pit"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: office cabinet"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: joke laugh"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: car driver"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: wall airport"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: army general"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: sunrise sunset"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: belt workshop"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: pigeon touch"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: second stopwatch"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: telescope astronomy"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: saucepan lid"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: jacket biology"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: cocoa chocolate"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: monkey jungle"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: walnut kernel"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: tailor needle"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: house scarf"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: basketball basket"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: vendor shop"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: resistance ohm"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: window curtain"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 95%. The next pair is: mechanic power"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bird lid"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: ship savannah"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: airplane airport"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: orchestra conductor"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: necklace flock"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: belt waist"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: artery river"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: second stopwatch"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: volleyball desert"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: frame stopper"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: microscope biology"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: screwdriver utensils"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: monkey jungle"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: poem pack"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: map principal"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: neck scarf"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: basketball basket"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: vendor shop"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bank child"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: window curtain"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: watt power"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: kilometer sty"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: coach sheet"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: airplane airport"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: orchestra conductor"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bird flock"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: belt waist"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: planet finger"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: artery blood"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: chair love"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bottle stopper"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: frame picture"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: screwdriver tools"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: cheetah savannah"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: garden stove"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: poem poet"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: microscope biology"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: volleyball point"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: mechanic workshop"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: donkey cloth"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: wall wallpaper"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: neck scarf"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: kilometer mile"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: coach athlete"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: kitchen cashier"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: ship port"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: company manager"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: necklace neck"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: pig sty"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 96%. The next pair is: seed virus"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: kiss love"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bottle stopper"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: frame picture"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: screwdriver tools"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: rabies racket"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bird flock"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: artery blood"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: map georgraphy"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: cheetah savannah"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: goal crying"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: mechanic workshop"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: wall wallpaper"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: poem poet"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: kilometer mile"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: length tentacle"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: kitchen stove"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: coach athlete"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: company manager"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: necklace neck"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: motor waiter"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: flu virus"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: seed plant"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: kiss love"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: ship port"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: membrane cheese"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: fork utensils"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: wolf pack"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: riverbed river"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: badminton racket"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: Celsius cue"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: goal mountain"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bank cashier"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: mattress sheet"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: map georgraphy"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: soccer roof"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: octopus tentacle"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: kitchen stove"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: pig sty"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: watt power"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: dolphin end"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: volleyball point"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: flu virus"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: seed plant"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: start rocker"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: master cyclist"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: membrane cell"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: fork utensils"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: wolf pack"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: riverbed river"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 96%. The next pair is: strike dough"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: badminton racket"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: goal mountain"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bank cashier"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: mattress sheet"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: border herd"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: house roof"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: octopus tentacle"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: voltage building"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: lion pipe"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: length meter"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: professor cake"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: camel clothes"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: parent dog"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: umbrella sea"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: motor rocker"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: master apprentice"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: start end"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: chair furniture"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: insult caffeine"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: membrane cell"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bread dough"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: strike pain"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: billiard cue"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: nurse hoof"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: restaurant waiter"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: sheep herd"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: house roof"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: millimeter bathroom"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: floor building"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: water pipe"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: length meter"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: ring mammal"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: camel desert"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: rabies dog"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: umbrella rain"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: motor rocker"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: centimeter yolk"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: master apprentice"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: chair furniture"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: insomnia caffeine"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: start end"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: crust thermometer"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bread dough"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: strike pain"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: donkey hoof"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: restaurant waiter"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bee mosquito"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: sheep herd"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bath bathroom"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 97%. The next pair is: millimeter line"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: floor building"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: hat parking"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: ring finger"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: voltage volt"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: embryo mammal"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: camel desert"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: school student"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bike cyclist"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: centimeter inch"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: shirt clothes"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: parent child"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: egg living-room"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: insomnia caffeine"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: umbrella rain"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: insult crying"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: donkey hoof"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: milk fence"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: billiard cue"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bee swarm"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bath bathroom"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: millimeter line"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: chess cold"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: car parking"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: crust pie"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: hat head"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: ring finger"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: floor taste"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: school principal"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: dolphin sea"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bike cyclist"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: embryo mammal"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: teacher hospital"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: egg yolk"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: shirt clothes"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: centimeter inch"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: voltage volt"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: euphoria clock"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: milk cheese"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: garden fence"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: parent child"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: couch living-room"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: hairdresser knife"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: chess check-mate"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: jacket cold"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: car parking"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: insult crying"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: skin station"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: hat head"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: school principal"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "your current accuracy is 97%. The next pair is: dolphin sea"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: crust pie"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: snail frame"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: nurse hospital"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: egg yolk"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: rabies dog"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: bee swarm"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: intoxication stick"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: euphoria drug"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: minute clock"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: garden fence"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: professor student"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: fruit core"
#  }
#  role: "user",
#  parts {
#    text: "NEW \n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: butcher knife"
#  }
#  role: "user",
#  parts {
#    text: "RECOMBINED \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: chess check-mate"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: couch living-room"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model",
#  parts {
#    text: "The next pair is: milk cheese"
#  }
#  role: "user",
#  parts {
#    text: "OLD \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n"
#  }
#  role: "model"]

# %% [markdown]
# # What's next

# %% [markdown]
# ## What's next
#
# To learn more about working with the Gemini API, see the [Python tutorial](https://ai.google.dev/tutorials/python_quickstart).
#
# If you're new to generative AI models, you might want to look at the
# [concepts guide](https://ai.google.dev/docs/concepts) and the
# [Gemini API overview](https://ai.google.dev/docs/gemini_api_overview).
